# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Wave Forms/test.csv')
df2 = pd.read_csv('../Wave Forms/test2.csv')

# %%
print (df)
# Out:
#       0.00244141
# 0       0.001831
# 1       0.001221
# 2       0.000610
# 3       0.000916
# 4       0.001221
# ...          ...
# 5114    0.445251
# 5115    0.420227
# 5116    0.394897
# 5117    0.368347
# 5118    0.341187
#
# [5119 rows x 1 columns]

# %%
plt.plot(df)

# %%
df2 = df2.drop(df2.index[0:14])
print (len(df2))
# Out:
# 5105

# %%
plt.plot(df2)

# %%
print(df2)
# Out:
#       0.00152588
# 14      0.001526
# 15      0.001526
# 16      0.001526
# 17      0.001221
# 18      0.001526
# ...          ...
# 5114    0.682068
# 5115    0.671387
# 5116    0.659180
# 5117    0.646057
# 5118    0.631409
#
# [5105 rows x 1 columns]

# %%
testdf = pd.read_csv('../Wave Forms/test3.csv' )

# %%
print(testdf)
# Out:
#            1
# 0
#  0         2
# -1         3
#  0         4
# -1         5
# -1         6
# ..       ...
#  51  1048570
#  59  1048571
#  42  1048572
#  43  1048573
#  21  1048574
#
# [1048573 rows x 1 columns]

# %%
plt.plot(testdf[testdf.columns[1]])

# %%
sam = pd.read_csv('../Wave Forms/sam.csv')
plt.plot(sam)

# %%
jt -l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 jt -l
#
# NameError: name 'jt' is not defined

# %%
pip install --upgrade jupyterthemes
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !jt -l
# Out:
# zsh:1: command not found: jt
